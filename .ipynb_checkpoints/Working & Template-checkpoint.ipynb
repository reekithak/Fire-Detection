# %%
from tensorflow.keras.preprocessing.image import load_img
import tensorflow.keras

# %%
model = tensorflow.keras.models.load_model('Model/model.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# sequential_1 (Sequential)    (None, 1280)              410208
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 3)                 128400
# ...
# Total params: 538,608
# Trainable params: 524,528
# Non-trainable params: 14,080
# _________________________________________________________________

# %%
from PIL import Image, ImageOps
from tensorflow.keras.preprocessing.image import load_img

# %%
unit_1 = load_img(r"D:\working repos\Fire-Detection\Not Required\Units-SequentialModel\Unit 1.jpg")

# %%
unit_2 = load_img(r"D:\working repos\Fire-Detection\Not Required\Units-SequentialModel\Unit 2.jpg")

# %%
unit_3 = load_img(r"D:\working repos\Fire-Detection\Not Required\Units-SequentialModel\Unit 3.jpg")

# %%
unit_1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x731 at 0x1F788C84288>

# %%
unit_2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=232x789 at 0x1F788C84548>

# %%
unit_3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=335x546 at 0x1F69DF34948>
